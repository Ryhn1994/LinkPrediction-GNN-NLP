# %%
import os
import numpy as np
import pandas as pd
import json
from itertools import product
import random

from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score, roc_auc_score, recall_score, precision_score, f1_score

import torch
import torch.nn.functional as F

from torch_geometric.nn import GCNConv
from torch_geometric.utils import train_test_split_edges, negative_sampling
from torch_geometric.data import Data, DataLoader, Dataset
from torch_geometric.data.dataset import Dataset


from transformers import BertTokenizer, BertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
def get_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).detach()

# %%
def create_bipartite_neg_edges(pos_edges, num_users, num_posts, num_neg_samples ):
    pos_edges_set = set(tuple(edge) for edge in pos_edges.T.tolist())
    sampled_neg_edges = []

    while len(sampled_neg_edges) < pos_edges.T.size(1):
        user = random.randint(0, num_users - 1)
        post = random.randint(num_users, num_users + num_posts - 1)
        edge = (user, post)
        if edge not in pos_edges_set:
            sampled_neg_edges.append(edge)

    return torch.tensor(sampled_neg_edges).T.contiguous()

# %%
class LinkpredictionDataset(Dataset):
    def __init__(self, pos_edge_index, neg_edge_index):
        self.pos_edge_index = pos_edge_index.T.tolist()
        self.neg_edge_index = neg_edge_index.T.tolist()
        self.labels = [1]*len(self.pos_edge_index) + [0]*len(self.neg_edge_index)
        self.edges = self.pos_edge_index + self.neg_edge_index
        
    def __len__(self):
        return len(self.edges)
    
    def __getitem__(self, idx) :
        return torch.tensor(self.edges[idx]), torch.tensor(self.labels[idx])

# %%
class LinkPredictor(torch.nn.Module):
    def __init__(self, in_channels):
        super(LinkPredictor, self).__init__()
        self.lin1 = torch.nn.Linear(in_channels*2, 1024)
        self.lin2 = torch.nn.Linear(1024, 512)
        self.lin3 = torch.nn.Linear(512, 256)
        self.lin4 = torch.nn.Linear(256, 128)
        self.lin5 = torch.nn.Linear(128, 64)
        self.lin6 = torch.nn.Linear(64, 1)

    def forward(self, edge_features):
        x = F.relu(self.lin1(edge_features))
        x = F.relu(self.lin2(x))
        x = F.relu(self.lin3(x))
        x = F.relu(self.lin4(x))
        x = F.relu(self.lin5(x))
        x = self.lin6(x)
        
        return torch.sigmoid(x)

# %%
if os.path.exists('reddit_comments_with_embedding.csv'):
    data = pd.read_csv('reddit_comments_with_embedding.csv')
    data['embeddings'] = data['embeddings'].apply(lambda x: torch.tensor(json.loads(x)))
else:
    data = pd.read_csv('reddit_comments.csv')
    data['body'] = data['body'].apply(lambda x: x.lower())
    data['embeddings'] = (data['body'].apply(get_bert_embeddings)).apply(lambda x: json.dumps(x.tolist()))
    data.to_csv('reddit_comments_with_embedding.csv')
    data['embeddings'] = data['embeddings'].apply(lambda x: torch.tensor(json.loads(x)))

# %%
user_ids = data["subreddit"].unique()
post_ids = data["submission_id"].unique()

user_id_map = {id: idx for idx,id in enumerate(user_ids)}
post_id_map = {id: idx + len(user_ids) for idx,id in enumerate(post_ids)}

edges = []
edge_features = []
for _, row in data.iterrows():
    user_id = row["subreddit"]
    post_id = row["submission_id"]
    embedding = np.array(row["embeddings"])
    normalized_embedding = normalize(embedding)[0]
    
    user_idx = user_id_map[user_id]
    post_idx = post_id_map[post_id]
    
    edges.append([user_idx, post_idx])
    edge_features.append(normalized_embedding)

edge_index = torch.tensor(edges).T.contiguous()
edge_attr = torch.tensor(edge_features)

num_nodes = len(user_ids) + len(post_ids)
node_features = torch.zeros(num_nodes, edge_attr.size(1))

for edge, feature in zip(edges, edge_features):
    user_idx, post_idx = edge
    node_features[user_idx] += torch.tensor(feature)
    node_features[post_idx] += torch.tensor(feature)
    
node_features = torch.tensor(normalize(node_features))
    


data = Data(x=node_features, edge_index=edge_index, edge_attr=edge_attr)

# %%
num_users = len(user_ids)
num_posts = len(post_ids)

train_pos_edge_index = random.sample(edges, int(0.2*(len(edges))))
val_pos_edge_index = random.sample([row for row in edges if row not in train_pos_edge_index], int(0.05*(len(edges))))
test_pos_edge_index = random.sample([row for row in edges if row not in (train_pos_edge_index+val_pos_edge_index)], int(0.05*(len(edges))))
train_pos_edge_index = (torch.tensor(train_pos_edge_index)).T
val_pos_edge_index = (torch.tensor(val_pos_edge_index)).T
test_pos_edge_index = (torch.tensor(test_pos_edge_index)).T

# %%
all_possible_edges = list(product(range(num_users), range(num_users, num_users+num_posts)))
pos_edges_set = set(tuple(edge) for edge in train_pos_edge_index.T.tolist())
all_possible_edges = [edge for edge in all_possible_edges if tuple(edge) not in pos_edges_set]
neg_edges = random.sample(all_possible_edges, train_pos_edge_index.size(1))
train_neg_edge_index = torch.tensor(neg_edges).T.contiguous()

# %%
all_possible_edges = list(product(range(num_users), range(num_users, num_users+num_posts)))
pos_edges_set = set(tuple(edge) for edge in val_pos_edge_index.T.tolist())
all_possible_edges = [edge for edge in all_possible_edges if tuple(edge) not in pos_edges_set]
neg_edges = random.sample(all_possible_edges, val_pos_edge_index.size(1))
val_neg_edge_index = torch.tensor(neg_edges).T.contiguous()

# %%
all_possible_edges = list(product(range(num_users), range(num_users, num_users+num_posts)))
pos_edges_set = set(tuple(edge) for edge in test_pos_edge_index.T.tolist())
all_possible_edges = [edge for edge in all_possible_edges if tuple(edge) not in pos_edges_set]
neg_edges = random.sample(all_possible_edges, test_pos_edge_index.size(1))
test_neg_edge_index = torch.tensor(neg_edges).T.contiguous()

# %%
train_edges_remove = (train_pos_edge_index.T.tolist())+(val_pos_edge_index.T.tolist())+(test_pos_edge_index.T.tolist())

train_adj = (torch.tensor([row for row in edges if row not in train_edges_remove])).T
val_adj = (torch.tensor(train_adj.T.tolist() + train_pos_edge_index.T.tolist())).T
test_adj = (torch.tensor(val_adj.T.tolist() + val_pos_edge_index.T.tolist())).T

# %%
train_dataset = LinkpredictionDataset(train_pos_edge_index, train_neg_edge_index)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)


val_dataset = LinkpredictionDataset(val_pos_edge_index, val_neg_edge_index)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)

test_dataset = LinkpredictionDataset(test_pos_edge_index, test_neg_edge_index)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)
# Out:
# C:\Users\asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

x = (data.x).to(torch.float32)
linkpredictor_model = LinkPredictor(x.size(1))
optimizer = torch.optim.Adam(linkpredictor_model.parameters(), lr=0.01)

# %%
def train(loader, x):
    
    linkpredictor_model.train()
    total_loss = 0
    for edges , labels in loader:
        edges = edges.T.contiguous()
        
        optimizer.zero_grad()

        
        edge_features = torch.cat([x[edges[0]], x[edges[1]]], dim=-1)
        preds = linkpredictor_model(edge_features).view(-1)
        
        loss = F.binary_cross_entropy(preds, labels.float())
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        
    return(total_loss/len(loader))

# %%
def test(pos_edge_index, neg_edge_index, x):

    linkpredictor_model.eval()
    
    with torch.no_grad():
        edge_features = torch.cat([x[pos_edge_index[0]], x[pos_edge_index[1]]], dim=-1)
        pos_pred = linkpredictor_model(edge_features).view(-1)
        edge_features = torch.cat([x[neg_edge_index[0]], x[neg_edge_index[1]]], dim=-1)
        neg_pred = linkpredictor_model(edge_features).view(-1)
        
    y_pred = torch.cat([pos_pred, neg_pred])
    y_true = torch.cat([torch.ones(pos_pred.size()), torch.zeros(neg_pred.size())])
    acc = accuracy_score(y_true, y_pred > 0.5)
    roc = roc_auc_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred > 0.5)
    prec = precision_score(y_true, y_pred > 0.5)
    f1 = f1_score(y_true, y_pred > 0.5)

    return acc, roc, rec, prec, f1

# %%
history = {"epoch":[],"Loss":[],"Validation Accuracy":[],"Validation ROC":[],"Validation Recall":[],"Validation Precision":[],"Validation F1":[]}
final_results = {"Loss":[],"Validation Accuracy":[],"Validation ROC":[],"Validation Recall":[],"Validation Precision":[],"Validation F1":[],
                 "Test Accuracy":[],"Test ROC":[],"Test Recall":[],"Test Precision":[],"Test F1":[]}

model_dir = 'models_weights'

# %%
for epoch in range(200):
    loss = train(train_loader,x)
    val_acc, val_roc, val_rec, val_prec, val_f1 = test(val_pos_edge_index, val_neg_edge_index, x)
    
    history["epoch"].append(epoch+1)
    history["Loss"].append(loss)
    history["Validation Accuracy"].append(val_acc)
    history["Validation ROC"].append(val_roc)
    history["Validation Recall"].append(val_rec)
    history["Validation Precision"].append(val_prec)
    history["Validation F1"].append(val_f1)
    
    linkpredictor_path = os.path.join(model_dir,f'linkpredictor_without_GNN_epoch_{epoch+1}.path')
    torch.save(linkpredictor_model.state_dict(), linkpredictor_path)
    
    print(f'\nEpoch {epoch+1},\nLoss: {loss},\nValidation Accuracy: {val_acc}, \nValidation ROC: {val_roc}, \nValidation Recall: {val_rec}, \nValidation Precision: {val_prec}, \nValidation F1: {val_f1} ')
    
test_acc, test_roc, test_rec, test_prec, test_f1 = test(test_pos_edge_index, test_neg_edge_index, x)

final_results["Loss"].append(loss)
final_results["Validation Accuracy"].append(val_acc)
final_results["Validation ROC"].append(val_roc)
final_results["Validation Recall"].append(val_rec)
final_results["Validation Precision"].append(val_prec)
final_results["Validation F1"].append(val_f1)
final_results["Test Accuracy"].append(test_acc)
final_results["Test ROC"].append(test_roc)
final_results["Test Recall"].append(test_rec)
final_results["Test Precision"].append(test_prec)
final_results["Test F1"].append(test_f1)

print(f'\n\n\nTest Accuracy: {test_acc}, \nTest ROC: {test_roc}, \nTest Recall: {test_rec}, \nTest Precision: {test_prec}, \nTest F1: {test_f1} ')
# Out:
# Epoch 1,
# Loss: 0.6763137408110529,
# Validation Accuracy: 0.5050978792822186,
# Validation ROC: 0.554259315563551,
# Validation Recall: 0.2092169657422512,
# Validation Precision: 0.5124875124875125,
# Validation F1: 0.29713292788879236
#
# Epoch 2,
# Loss: 0.6118559900440689,
# Validation Accuracy: 0.54221044045677,
# Validation ROC: 0.5470823664272465,
# Validation Recall: 0.5314029363784666,
# Validation Precision: 0.5431429762401,
# Validation F1: 0.5372088229231087
#
# Epoch 3,
# Loss: 0.5880480593112859,
# Validation Accuracy: 0.5320146818923328,
# Validation ROC: 0.5826250635363748,
# Validation Recall: 0.32137030995106036,
# Validation Precision: 0.5553206483439042,
# Validation F1: 0.40712994058382845
#
# Epoch 4,
# Loss: 0.5682798100799225,
# Validation Accuracy: 0.5462887438825449,
# Validation ROC: 0.6145198246795239,
# Validation Recall: 0.25570962479608483,
# Validation Precision: 0.6105160662122687,
# Validation F1: 0.36044840471399825
#
# Epoch 5,
# Loss: 0.5445478337207136,
# Validation Accuracy: 0.577283849918434,
# Validation ROC: 0.6280786866399304,
# Validation Recall: 0.4074225122349103,
# Validation Precision: 0.6170475602223595,
# Validation F1: 0.49078850405305824
#
# Epoch 6,
# Loss: 0.5234947335642401,
# Validation Accuracy: 0.572389885807504,
# Validation ROC: 0.6718747089302205,
# Validation Recall: 0.28629690048939643,
# Validation Precision: 0.669208770257388,
# Validation F1: 0.40102827763496146
#
# Epoch 7,
# Loss: 0.4989962538018677,
# Validation Accuracy: 0.589110929853181,
# Validation ROC: 0.6847152106746432,
# Validation Recall: 0.33727569331158236,
# Validation Precision: 0.6795398520953163,
# Validation F1: 0.45080403379667483
#
# Epoch 8,
# Loss: 0.4768974471364037,
# Validation Accuracy: 0.625,
# Validation ROC: 0.7079158838275643,
# Validation Recall: 0.44494290375203915,
# Validation Precision: 0.6953473550031868,
# Validation F1: 0.5426510818204426
#
# Epoch 9,
# Loss: 0.4665438308583797,
# Validation Accuracy: 0.6347879282218597,
# Validation ROC: 0.7229419038026021,
# Validation Recall: 0.4535073409461664,
# Validation Precision: 0.7114523352527191,
# Validation F1: 0.5539227895392279
#
# Epoch 10,
# Loss: 0.4575448258497816,
# Validation Accuracy: 0.5976753670473083,
# Validation ROC: 0.7374362640345531,
# Validation Recall: 0.27895595432300163,
# Validation Precision: 0.7694038245219348,
# Validation F1: 0.4094582460341215
#
# Epoch 11,
# Loss: 0.4358971411125668,
# Validation Accuracy: 0.5976753670473083,
# Validation ROC: 0.7369136690360301,
# Validation Recall: 0.2671288743882545,
# Validation Precision: 0.7882069795427196,
# Validation F1: 0.39902528175449287
#
# Epoch 12,
# Loss: 0.43010683275201034,
# Validation Accuracy: 0.6706769983686787,
# Validation ROC: 0.7452504064997378,
# Validation Recall: 0.5530179445350734,
# Validation Precision: 0.7232,
# Validation F1: 0.6267621908943841
#
# Epoch 13,
# Loss: 0.42090937543769613,
# Validation Accuracy: 0.6761827079934747,
# Validation ROC: 0.734812644204285,
# Validation Recall: 0.6631321370309952,
# Validation Precision: 0.6809045226130653,
# Validation F1: 0.671900826446281
#
# Epoch 14,
# Loss: 0.4092202352584379,
# Validation Accuracy: 0.6733278955954323,
# Validation ROC: 0.757008294989741,
# Validation Recall: 0.5615823817292006,
# Validation Precision: 0.7232142857142857,
# Validation F1: 0.6322314049586777
#
# Epoch 15,
# Loss: 0.4016593018067388,
# Validation Accuracy: 0.6468189233278956,
# Validation ROC: 0.7488113541830221,
# Validation Recall: 0.466557911908646,
# Validation Precision: 0.7295918367346939,
# Validation F1: 0.5691542288557214
#
# Epoch 16,
# Loss: 0.40178349754903525,
# Validation Accuracy: 0.6460032626427407,
# Validation ROC: 0.7624180347500724,
# Validation Recall: 0.43066884176182707,
# Validation Precision: 0.7564469914040115,
# Validation F1: 0.5488565488565489
#
# Epoch 17,
# Loss: 0.3916569417676242,
# Validation Accuracy: 0.6684339314845025,
# Validation ROC: 0.7508680532454778,
# Validation Recall: 0.5415986949429038,
# Validation Precision: 0.7256830601092896,
# Validation F1: 0.6202709014479215
#
# Epoch 18,
# Loss: 0.39066782152031454,
# Validation Accuracy: 0.6698613376835236,
# Validation ROC: 0.769243371592654,
# Validation Recall: 0.5048939641109299,
# Validation Precision: 0.7534996956786366,
# Validation F1: 0.6046398046398046
#
# Epoch 19,
# Loss: 0.3842280514853785,
# Validation Accuracy: 0.6804649265905384,
# Validation ROC: 0.7478425907938121,
# Validation Recall: 0.6305057096247961,
# Validation Precision: 0.7004984141368373,
# Validation F1: 0.6636617299849753
#
# Epoch 20,
# Loss: 0.38093232443550124,
# Validation Accuracy: 0.6700652528548124,
# Validation ROC: 0.7689855669307473,
# Validation Recall: 0.5053017944535073,
# Validation Precision: 0.7536496350364964,
# Validation F1: 0.60498046875
#
# Epoch 21,
# Loss: 0.3793874728077786,
# Validation Accuracy: 0.6873980424143556,
# Validation ROC: 0.7565821688324477,
# Validation Recall: 0.6594616639477977,
# Validation Precision: 0.698488120950324,
# Validation F1: 0.6784140969162996
#
# Epoch 22,
# Loss: 0.37586042600462416,
# Validation Accuracy: 0.692699836867863,
# Validation ROC: 0.761489605316032,
# Validation Recall: 0.6411092985318108,
# Validation Precision: 0.7148703956343793,
# Validation F1: 0.67598365942808
#
# Epoch 23,
# Loss: 0.361779142134741,
# Validation Accuracy: 0.6931076672104405,
# Validation ROC: 0.759875581806908,
# Validation Recall: 0.6349918433931484,
# Validation Precision: 0.7185048454083988,
# Validation F1: 0.6741718986793678
#
# Epoch 24,
# Loss: 0.36556083298855574,
# Validation Accuracy: 0.6975938009787929,
# Validation ROC: 0.7655613388810679,
# Validation Recall: 0.7059543230016313,
# Validation Precision: 0.694344163658243,
# Validation F1: 0.7001011122345804
#
# Epoch 25,
# Loss: 0.361140883561066,
# Validation Accuracy: 0.6939233278955954,
# Validation ROC: 0.7606659610026373,
# Validation Recall: 0.6309135399673735,
# Validation Precision: 0.7218852076528232,
# Validation F1: 0.6733405875952122
#
# Epoch 26,
# Loss: 0.357555218502054,
# Validation Accuracy: 0.6967781402936378,
# Validation ROC: 0.7641484861710253,
# Validation Recall: 0.6570146818923328,
# Validation Precision: 0.7137793531236154,
# Validation F1: 0.6842217031216818
#
# Epoch 27,
# Loss: 0.35282445220877373,
# Validation Accuracy: 0.6294861337683524,
# Validation ROC: 0.7642245801276848,
# Validation Recall: 0.36133768352365414,
# Validation Precision: 0.7792436235708003,
# Validation F1: 0.49373084424630814
#
# Epoch 28,
# Loss: 0.35504651341453825,
# Validation Accuracy: 0.6951468189233279,
# Validation ROC: 0.7661739160228758,
# Validation Recall: 0.6843393148450244,
# Validation Precision: 0.6994581075448103,
# Validation F1: 0.6918161203875489
#
# Epoch 29,
# Loss: 0.3415482555810326,
# Validation Accuracy: 0.6898450244698205,
# Validation ROC: 0.7630224619380523,
# Validation Recall: 0.6166394779771615,
# Validation Precision: 0.7224080267558528,
# Validation F1: 0.6653465346534654
#
# Epoch 30,
# Loss: 0.3455452056486366,
# Validation Accuracy: 0.6935154975530179,
# Validation ROC: 0.7763548716099518,
# Validation Recall: 0.5942088091353996,
# Validation Precision: 0.7414758269720102,
# Validation F1: 0.659723794430609
#
# Epoch 31,
# Loss: 0.334396199411212,
# Validation Accuracy: 0.6912724306688418,
# Validation ROC: 0.7667162206036157,
# Validation Recall: 0.6113376835236541,
# Validation Precision: 0.7276699029126213,
# Validation F1: 0.6644503546099291
#
# Epoch 32,
# Loss: 0.3419382436753096,
# Validation Accuracy: 0.6994290375203915,
# Validation ROC: 0.7687142898961862,
# Validation Recall: 0.651305057096248,
# Validation Precision: 0.7206678700361011,
# Validation F1: 0.6842330762639246
#
# Epoch 33,
# Loss: 0.3344452272894328,
# Validation Accuracy: 0.682300163132137,
# Validation ROC: 0.7582354451804167,
# Validation Recall: 0.5929853181076672,
# Validation Precision: 0.7219463753723933,
# Validation F1: 0.651141961486789
#
# Epoch 34,
# Loss: 0.33472902587454173,
# Validation Accuracy: 0.6810766721044046,
# Validation ROC: 0.7615321846666436,
# Validation Recall: 0.5705546492659054,
# Validation Precision: 0.7324607329842932,
# Validation F1: 0.6414488766620816
#
# Epoch 35,
# Loss: 0.3262714758175592,
# Validation Accuracy: 0.6645595432300163,
# Validation ROC: 0.760497390018868,
# Validation Recall: 0.48817292006525287,
# Validation Precision: 0.7542533081285444,
# Validation F1: 0.5927209705372617
#
# Epoch 36,
# Loss: 0.32139722464138987,
# Validation Accuracy: 0.6774061990212071,
# Validation ROC: 0.7667258674877384,
# Validation Recall: 0.535889070146819,
# Validation Precision: 0.7474402730375427,
# Validation F1: 0.624228028503563
#
# Epoch 37,
# Loss: 0.32964725394396516,
# Validation Accuracy: 0.6739396411092985,
# Validation ROC: 0.7617980561195841,
# Validation Recall: 0.5305872756933115,
# Validation Precision: 0.7438536306460835,
# Validation F1: 0.6193763389669127
#
# Epoch 38,
# Loss: 0.3241829202792543,
# Validation Accuracy: 0.691884176182708,
# Validation ROC: 0.7704165491299177,
# Validation Recall: 0.6243882544861338,
# Validation Precision: 0.7218293257897218,
# Validation F1: 0.6695823310736935
#
# Epoch 39,
# Loss: 0.3198343897390055,
# Validation Accuracy: 0.6920880913539967,
# Validation ROC: 0.7616673242071591,
# Validation Recall: 0.6056280587275693,
# Validation Precision: 0.7322485207100592,
# Validation F1: 0.6629464285714286
#
# Epoch 40,
# Loss: 0.3122567197350415,
# Validation Accuracy: 0.6876019575856444,
# Validation ROC: 0.7673479251880809,
# Validation Recall: 0.6064437194127243,
# Validation Precision: 0.7239532619279455,
# Validation F1: 0.6600088770528184
#
# Epoch 41,
# Loss: 0.31007982411873847,
# Validation Accuracy: 0.6800570962479608,
# Validation ROC: 0.764208446545617,
# Validation Recall: 0.5738172920065253,
# Validation Precision: 0.7286380113930606,
# Validation F1: 0.6420260095824778
#
# Epoch 42,
# Loss: 0.3067803919218262,
# Validation Accuracy: 0.6606851549755302,
# Validation ROC: 0.764254186082407,
# Validation Recall: 0.4694127243066884,
# Validation Precision: 0.7602377807133421,
# Validation F1: 0.5804336863338376
#
# Epoch 43,
# Loss: 0.3038024371338201,
# Validation Accuracy: 0.6863784665579119,
# Validation ROC: 0.7586289715223982,
# Validation Recall: 0.5905383360522023,
# Validation Precision: 0.7305751765893037,
# Validation F1: 0.6531348669373027
#
# Epoch 44,
# Loss: 0.3050465280924247,
# Validation Accuracy: 0.6808727569331158,
# Validation ROC: 0.7640736396562782,
# Validation Recall: 0.5522022838499184,
# Validation Precision: 0.7435475013728721,
# Validation F1: 0.6337467821202902
#
# Epoch 45,
# Loss: 0.31255573048847896,
# Validation Accuracy: 0.6914763458401305,
# Validation ROC: 0.7690476063751933,
# Validation Recall: 0.5966557911908646,
# Validation Precision: 0.7362858580775038,
# Validation F1: 0.6591574678981753
#
# Epoch 46,
# Loss: 0.30090652537268225,
# Validation Accuracy: 0.6682300163132137,
# Validation ROC: 0.7436795444807848,
# Validation Recall: 0.5966557911908646,
# Validation Precision: 0.6963350785340314,
# Validation F1: 0.642653195695146
#
# Epoch 47,
# Loss: 0.3064210531377637,
# Validation Accuracy: 0.6871941272430668,
# Validation ROC: 0.7656886611189322,
# Validation Recall: 0.5901305057096248,
# Validation Precision: 0.7322874493927125,
# Validation F1: 0.6535682023486902
#
# Epoch 48,
# Loss: 0.30698210864967945,
# Validation Accuracy: 0.6937194127243067,
# Validation ROC: 0.7660302107145613,
# Validation Recall: 0.6349918433931484,
# Validation Precision: 0.7195009242144177,
# Validation F1: 0.6746100519930676
#
# Epoch 49,
# Loss: 0.34666559925296797,
# Validation Accuracy: 0.649673735725938,
# Validation ROC: 0.7261662916579069,
# Validation Recall: 0.5285481239804242,
# Validation Precision: 0.697524219590958,
# Validation F1: 0.6013921113689095
#
# Epoch 50,
# Loss: 0.324789403558554,
# Validation Accuracy: 0.6767944535073409,
# Validation ROC: 0.760289815684636,
# Validation Recall: 0.5840130505709625,
# Validation Precision: 0.7170756134201302,
# Validation F1: 0.6437401663295123
#
# Epoch 51,
# Loss: 0.31335927978012384,
# Validation Accuracy: 0.6769983686786297,
# Validation ROC: 0.7602168819141548,
# Validation Recall: 0.5742251223491027,
# Validation Precision: 0.7227926078028748,
# Validation F1: 0.64
#
# Epoch 52,
# Loss: 0.3034029480931425,
# Validation Accuracy: 0.6892332789559543,
# Validation ROC: 0.7697727859402984,
# Validation Recall: 0.5730016313213703,
# Validation Precision: 0.7465462274176408,
# Validation F1: 0.6483617904937702
#
# Epoch 53,
# Loss: 0.30449421961066775,
# Validation Accuracy: 0.6739396411092985,
# Validation ROC: 0.7589891495839199,
# Validation Recall: 0.5411908646003263,
# Validation Precision: 0.7368128817323709,
# Validation F1: 0.6240300964025394
#
# Epoch 54,
# Loss: 0.30912160213296497,
# Validation Accuracy: 0.6794453507340946,
# Validation ROC: 0.7578133108372431,
# Validation Recall: 0.5546492659053833,
# Validation Precision: 0.7391304347826086,
# Validation F1: 0.6337371854613234
#
# Epoch 55,
# Loss: 0.3163795415858104,
# Validation Accuracy: 0.685562805872757,
# Validation ROC: 0.7708300345424982,
# Validation Recall: 0.5742251223491027,
# Validation Precision: 0.7387198321091291,
# Validation F1: 0.6461679669573198
#
# Epoch 56,
# Loss: 0.29453707877121843,
# Validation Accuracy: 0.6678221859706363,
# Validation ROC: 0.7499096020427443,
# Validation Recall: 0.5640293637846656,
# Validation Precision: 0.7117858980957282,
# Validation F1: 0.6293515358361774
#
# Epoch 57,
# Loss: 0.2992743473099575,
# Validation Accuracy: 0.6975938009787929,
# Validation ROC: 0.7678257786033442,
# Validation Recall: 0.6390701468189234,
# Validation Precision: 0.7237875288683603,
# Validation F1: 0.6787957548191467
#
# Epoch 58,
# Loss: 0.29779419370893545,
# Validation Accuracy: 0.6733278955954323,
# Validation ROC: 0.7680513161011153,
# Validation Recall: 0.5101957585644372,
# Validation Precision: 0.7572639225181598,
# Validation F1: 0.6096491228070176
#
# Epoch 59,
# Loss: 0.28972415048447026,
# Validation Accuracy: 0.6900489396411092,
# Validation ROC: 0.7595976517488138,
# Validation Recall: 0.6529363784665579,
# Validation Precision: 0.7052863436123348,
# Validation F1: 0.6781024989411266
#
# Epoch 60,
# Loss: 0.2917148119948974,
# Validation Accuracy: 0.6886215334420881,
# Validation ROC: 0.7541407586841916,
# Validation Recall: 0.6745513866231647,
# Validation Precision: 0.6940830885438523,
# Validation F1: 0.6841778697001034
#
# Epoch 61,
# Loss: 0.2895607234794853,
# Validation Accuracy: 0.6719004893964111,
# Validation ROC: 0.7676066446407235,
# Validation Recall: 0.5,
# Validation Precision: 0.761963952765693,
# Validation F1: 0.6037921694163999
#
# Epoch 62,
# Loss: 0.285285717986694,
# Validation Accuracy: 0.683931484502447,
# Validation ROC: 0.753306469533144,
# Validation Recall: 0.6097063621533442,
# Validation Precision: 0.7159961685823755,
# Validation F1: 0.6585903083700441
#
# Epoch 63,
# Loss: 0.28707068357677334,
# Validation Accuracy: 0.6804649265905384,
# Validation ROC: 0.7597823563146507,
# Validation Recall: 0.583605220228385,
# Validation Precision: 0.723823975720789,
# Validation F1: 0.6461955294648905
#
# Epoch 64,
# Loss: 0.278226573954576,
# Validation Accuracy: 0.6880097879282219,
# Validation ROC: 0.7576757595756968,
# Validation Recall: 0.6447797716150081,
# Validation Precision: 0.7058035714285714,
# Validation F1: 0.6739130434782609
#
# Epoch 65,
# Loss: 0.28641817053773894,
# Validation Accuracy: 0.6965742251223491,
# Validation ROC: 0.7649614024839729,
# Validation Recall: 0.6541598694942904,
# Validation Precision: 0.714795008912656,
# Validation F1: 0.6831345826235093
#
# Epoch 66,
# Loss: 0.2904459566654522,
# Validation Accuracy: 0.6863784665579119,
# Validation ROC: 0.7558330383826234,
# Validation Recall: 0.6472267536704731,
# Validation Precision: 0.702212389380531,
# Validation F1: 0.6735993208828522
#
# Epoch 67,
# Loss: 0.2954952346482572,
# Validation Accuracy: 0.6829119086460033,
# Validation ROC: 0.7557951161484849,
# Validation Recall: 0.6105220228384992,
# Validation Precision: 0.7138769670958512,
# Validation F1: 0.6581666300285777
#
# Epoch 68,
# Loss: 0.2776954489538646,
# Validation Accuracy: 0.6761827079934747,
# Validation ROC: 0.7622161154858436,
# Validation Recall: 0.5469004893964111,
# Validation Precision: 0.7376237623762376,
# Validation F1: 0.6281030444964871
#
# Epoch 69,
# Loss: 0.27312679103414866,
# Validation Accuracy: 0.6869902120717781,
# Validation ROC: 0.763372826789863,
# Validation Recall: 0.6199021207177814,
# Validation Precision: 0.7159679698539803,
# Validation F1: 0.6644808743169399
#
# Epoch 70,
# Loss: 0.282404555317245,
# Validation Accuracy: 0.6617047308319739,
# Validation ROC: 0.7598453937126266,
# Validation Recall: 0.48450244698205547,
# Validation Precision: 0.7504737839545167,
# Validation F1: 0.5888475836431227
#
# Epoch 71,
# Loss: 0.2756795784646603,
# Validation Accuracy: 0.6796492659053833,
# Validation ROC: 0.7556326160486895,
# Validation Recall: 0.6097063621533442,
# Validation Precision: 0.7088667614983405,
# Validation F1: 0.6555579916684937
#
# Epoch 72,
# Loss: 0.284193639476641,
# Validation Accuracy: 0.6645595432300163,
# Validation ROC: 0.752279076374049,
# Validation Recall: 0.5579119086460033,
# Validation Precision: 0.7091757387247278,
# Validation F1: 0.6245149509244464
#
# Epoch 73,
# Loss: 0.2798345942256505,
# Validation Accuracy: 0.6857667210440457,
# Validation ROC: 0.7582145713190817,
# Validation Recall: 0.6125611745513866,
# Validation Precision: 0.7176301958910655,
# Validation F1: 0.660946094609461
#
# Epoch 74,
# Loss: 0.28593407532485376,
# Validation Accuracy: 0.6682300163132137,
# Validation ROC: 0.7498479784122692,
# Validation Recall: 0.5460848287112561,
# Validation Precision: 0.7226119805720453,
# Validation F1: 0.6220673635307782
#
# Epoch 75,
# Loss: 0.28062337343292826,
# Validation Accuracy: 0.6853588907014682,
# Validation ROC: 0.7573133361187324,
# Validation Recall: 0.6011419249592169,
# Validation Precision: 0.7229033840117705,
# Validation F1: 0.6564239590291695
#
# Epoch 76,
# Loss: 0.2725374450367126,
# Validation Accuracy: 0.6747553017944535,
# Validation ROC: 0.7557152798660879,
# Validation Recall: 0.5428221859706363,
# Validation Precision: 0.7373961218836566,
# Validation F1: 0.6253229974160207
#
# Epoch 77,
# Loss: 0.27309524420806564,
# Validation Accuracy: 0.6676182707993474,
# Validation ROC: 0.7571524992748204,
# Validation Recall: 0.5228384991843393,
# Validation Precision: 0.7359357060849598,
# Validation F1: 0.6113495469718646
#
# Epoch 78,
# Loss: 0.26718581072282327,
# Validation Accuracy: 0.6780179445350734,
# Validation ROC: 0.7543927419505068,
# Validation Recall: 0.5872756933115824,
# Validation Precision: 0.7174887892376681,
# Validation F1: 0.6458847275173806
#
# Epoch 79,
# Loss: 0.2576731346571873,
# Validation Accuracy: 0.6808727569331158,
# Validation ROC: 0.7539170507678921,
# Validation Recall: 0.6117455138662317,
# Validation Precision: 0.709891150023663,
# Validation F1: 0.6571741511500547
#
# Epoch 80,
# Loss: 0.26646606311056437,
# Validation Accuracy: 0.6774061990212071,
# Validation ROC: 0.7494779871410362,
# Validation Recall: 0.6146003262642741,
# Validation Precision: 0.7028917910447762,
# Validation F1: 0.6557876414273281
#
# Epoch 81,
# Loss: 0.2734282349239343,
# Validation Accuracy: 0.6873980424143556,
# Validation ROC: 0.7514665758750722,
# Validation Recall: 0.6688417618270799,
# Validation Precision: 0.6946209233375689,
# Validation F1: 0.6814876376480365
#
# Epoch 82,
# Loss: 0.27148966581017653,
# Validation Accuracy: 0.6741435562805873,
# Validation ROC: 0.7510110100886449,
# Validation Recall: 0.5770799347471451,
# Validation Precision: 0.7160931174089069,
# Validation F1: 0.6391147244805782
#
# Epoch 83,
# Loss: 0.2698608112403158,
# Validation Accuracy: 0.6802610114192496,
# Validation ROC: 0.7526538079245494,
# Validation Recall: 0.6353996737357259,
# Validation Precision: 0.6980286738351255,
# Validation F1: 0.6652433817250214
#
# Epoch 84,
# Loss: 0.27247024463422914,
# Validation Accuracy: 0.6774061990212071,
# Validation ROC: 0.7515548115996796,
# Validation Recall: 0.6052202283849919,
# Validation Precision: 0.7073403241182078,
# Validation F1: 0.6523076923076923
#
# Epoch 85,
# Loss: 0.2764871994864669,
# Validation Accuracy: 0.6710848287112561,
# Validation ROC: 0.7307821593851542,
# Validation Recall: 0.6782218597063622,
# Validation Precision: 0.6686771210293526,
# Validation F1: 0.6734156711884997
#
# Epoch 86,
# Loss: 0.2745063737617254,
# Validation Accuracy: 0.6731239804241436,
# Validation ROC: 0.7496453938456871,
# Validation Recall: 0.5970636215334421,
# Validation Precision: 0.7041847041847041,
# Validation F1: 0.6462149635841977
#
# Epoch 87,
# Loss: 0.25774062000190784,
# Validation Accuracy: 0.6816884176182708,
# Validation ROC: 0.7529729867285487,
# Validation Recall: 0.6390701468189234,
# Validation Precision: 0.6986179224253233,
# Validation F1: 0.6675186368477103
#
# Epoch 88,
# Loss: 0.25694827104430246,
# Validation Accuracy: 0.6617047308319739,
# Validation ROC: 0.7468992752196163,
# Validation Recall: 0.5248776508972267,
# Validation Precision: 0.7226277372262774,
# Validation F1: 0.6080793763288448
#
# Epoch 89,
# Loss: 0.2703709280063741,
# Validation Accuracy: 0.6786296900489397,
# Validation ROC: 0.7512114324225788,
# Validation Recall: 0.6182707993474714,
# Validation Precision: 0.7031539888682746,
# Validation F1: 0.6579861111111112
#
# Epoch 90,
# Loss: 0.2644865440526304,
# Validation Accuracy: 0.6725122349102773,
# Validation ROC: 0.7510925096269251,
# Validation Recall: 0.5656606851549756,
# Validation Precision: 0.7193983402489627,
# Validation F1: 0.6333333333333333
#
# Epoch 91,
# Loss: 0.2573706164033871,
# Validation Accuracy: 0.672716150081566,
# Validation ROC: 0.749314156436534,
# Validation Recall: 0.5840130505709625,
# Validation Precision: 0.7099652949925632,
# Validation F1: 0.6408592526292235
#
# Epoch 92,
# Loss: 0.2743284206485515,
# Validation Accuracy: 0.683115823817292,
# Validation ROC: 0.7533147026497662,
# Validation Recall: 0.6309135399673735,
# Validation Precision: 0.7044626593806922,
# Validation F1: 0.6656626506024096
#
# Epoch 93,
# Loss: 0.25773693817737436,
# Validation Accuracy: 0.6700652528548124,
# Validation ROC: 0.7471260601592999,
# Validation Recall: 0.5640293637846656,
# Validation Precision: 0.7158385093167702,
# Validation F1: 0.6309306569343066
#
# Epoch 94,
# Loss: 0.2621640214751132,
# Validation Accuracy: 0.6641517128874388,
# Validation ROC: 0.7419752061771994,
# Validation Recall: 0.5420065252854812,
# Validation Precision: 0.7172153264975715,
# Validation F1: 0.6174216027874564
#
# Epoch 95,
# Loss: 0.2554485086800609,
# Validation Accuracy: 0.6710848287112561,
# Validation ROC: 0.751447697920797,
# Validation Recall: 0.5766721044045677,
# Validation Precision: 0.7109100050276521,
# Validation F1: 0.636793514974105
#
# Epoch 96,
# Loss: 0.2602387318684923,
# Validation Accuracy: 0.6694535073409462,
# Validation ROC: 0.7530350261729946,
# Validation Recall: 0.5362969004893964,
# Validation Precision: 0.7309616453585325,
# Validation F1: 0.6186779581274994
#
# Epoch 97,
# Loss: 0.24987559311747162,
# Validation Accuracy: 0.6857667210440457,
# Validation ROC: 0.7546033933081229,
# Validation Recall: 0.6455954323001631,
# Validation Precision: 0.7019955654101996,
# Validation F1: 0.6726152538772041
#
# Epoch 98,
# Loss: 0.25529673465008845,
# Validation Accuracy: 0.6778140293637847,
# Validation ROC: 0.7499905194414653,
# Validation Recall: 0.6398858075040783,
# Validation Precision: 0.6924095322153575,
# Validation F1: 0.6651123357354811
#
# Epoch 99,
# Loss: 0.2488892237118867,
# Validation Accuracy: 0.6751631321370309,
# Validation ROC: 0.745927767458199,
# Validation Recall: 0.5970636215334421,
# Validation Precision: 0.707588206863219,
# Validation F1: 0.6476443264764432
#
# Epoch 100,
# Loss: 0.25244482555684516,
# Validation Accuracy: 0.6747553017944535,
# Validation ROC: 0.7416664227224704,
# Validation Recall: 0.6464110929853181,
# Validation Precision: 0.6852572416774751,
# Validation F1: 0.6652675760755509
#
# Epoch 101,
# Loss: 0.2534249798191487,
# Validation Accuracy: 0.675978792822186,
# Validation ROC: 0.7480940750833625,
# Validation Recall: 0.6186786296900489,
# Validation Precision: 0.6987563334868724,
# Validation F1: 0.6562837983993078
#
# Epoch 102,
# Loss: 0.2703513605247103,
# Validation Accuracy: 0.6435562805872757,
# Validation ROC: 0.7042233726039135,
# Validation Recall: 0.6757748776508973,
# Validation Precision: 0.6348659003831417,
# Validation F1: 0.6546819438956935
#
# Epoch 103,
# Loss: 0.26486256636120986,
# Validation Accuracy: 0.6737357259380098,
# Validation ROC: 0.7515633773674785,
# Validation Recall: 0.5497553017944535,
# Validation Precision: 0.7310195227765727,
# Validation F1: 0.62756052141527
#
# Epoch 104,
# Loss: 0.24874035494723615,
# Validation Accuracy: 0.6837275693311582,
# Validation ROC: 0.7511885626541839,
# Validation Recall: 0.6353996737357259,
# Validation Precision: 0.7033860045146727,
# Validation F1: 0.6676665952431969
#
# Epoch 105,
# Loss: 0.25338786391462487,
# Validation Accuracy: 0.66721044045677,
# Validation ROC: 0.7478560631664666,
# Validation Recall: 0.5456769983686787,
# Validation Precision: 0.7209051724137931,
# Validation F1: 0.6211699164345403
#
# Epoch 106,
# Loss: 0.3389415423528379,
# Validation Accuracy: 0.6582381729200653,
# Validation ROC: 0.7281200351811885,
# Validation Recall: 0.5399673735725938,
# Validation Precision: 0.7072649572649573,
# Validation F1: 0.6123959296947271
#
# Epoch 107,
# Loss: 0.27356467417862984,
# Validation Accuracy: 0.6655791190864601,
# Validation ROC: 0.7521769524628164,
# Validation Recall: 0.5154975530179445,
# Validation Precision: 0.7365967365967366,
# Validation F1: 0.6065259117082533
#
# Epoch 108,
# Loss: 0.2561339234344734,
# Validation Accuracy: 0.6735318107667211,
# Validation ROC: 0.751442042850794,
# Validation Recall: 0.6023654159869495,
# Validation Precision: 0.7023300047551118,
# Validation F1: 0.6485181119648737
#
# Epoch 109,
# Loss: 0.2471212015429615,
# Validation Accuracy: 0.6712887438825449,
# Validation ROC: 0.7439901575169853,
# Validation Recall: 0.5607667210440457,
# Validation Precision: 0.7198952879581152,
# Validation F1: 0.6304447501146263
#
# Epoch 110,
# Loss: 0.2539325795266838,
# Validation Accuracy: 0.6737357259380098,
# Validation ROC: 0.7500376727457561,
# Validation Recall: 0.5999184339314845,
# Validation Precision: 0.7038277511961722,
# Validation F1: 0.647732276530163
#
# Epoch 111,
# Loss: 0.24858374886384615,
# Validation Accuracy: 0.6692495921696574,
# Validation ROC: 0.7474802504996421,
# Validation Recall: 0.5754486133768353,
# Validation Precision: 0.7083333333333334,
# Validation F1: 0.635013501350135
#
# Epoch 112,
# Loss: 0.24710381778521337,
# Validation Accuracy: 0.6714926590538336,
# Validation ROC: 0.7435998745239762,
# Validation Recall: 0.5880913539967374,
# Validation Precision: 0.7058247674987763,
# Validation F1: 0.6416017797552837
#
# Epoch 113,
# Loss: 0.48667028757473546,
# Validation Accuracy: 0.6541598694942904,
# Validation ROC: 0.7231464011134501,
# Validation Recall: 0.5648450244698205,
# Validation Precision: 0.6876861966236345,
# Validation F1: 0.6202418271383788
#
# Epoch 114,
# Loss: 0.39941534001974793,
# Validation Accuracy: 0.5974714518760196,
# Validation ROC: 0.6557500252814894,
# Validation Recall: 0.42781402936378465,
# Validation Precision: 0.6475308641975308,
# Validation F1: 0.5152259332023575
#
# Epoch 115,
# Loss: 0.3834335571974031,
# Validation Accuracy: 0.6629282218597063,
# Validation ROC: 0.7445684715875978,
# Validation Recall: 0.5415986949429038,
# Validation Precision: 0.7151319332256327,
# Validation F1: 0.6163843119053145
#
# Epoch 116,
# Loss: 0.3361210935667206,
# Validation Accuracy: 0.6802610114192496,
# Validation ROC: 0.7546917953583185,
# Validation Recall: 0.5880913539967374,
# Validation Precision: 0.721,
# Validation F1: 0.6477987421383647
#
# Epoch 117,
# Loss: 0.32729447417034,
# Validation Accuracy: 0.6863784665579119,
# Validation ROC: 0.75677876567785,
# Validation Recall: 0.5950244698205547,
# Validation Precision: 0.7280439121756487,
# Validation F1: 0.6548473967684022
#
# Epoch 118,
# Loss: 0.3191951720062219,
# Validation Accuracy: 0.6657830342577488,
# Validation ROC: 0.7583279222075264,
# Validation Recall: 0.4873572593800979,
# Validation Precision: 0.7577679137603044,
# Validation F1: 0.5931993050384711
#
# Epoch 119,
# Loss: 0.3145313982757761,
# Validation Accuracy: 0.6739396411092985,
# Validation ROC: 0.7572358283945723,
# Validation Recall: 0.5289559543230016,
# Validation Precision: 0.7449741527857553,
# Validation F1: 0.6186501311709993
#
# Epoch 120,
# Loss: 0.3107659339613557,
# Validation Accuracy: 0.6967781402936378,
# Validation ROC: 0.7594514515566745,
# Validation Recall: 0.6150081566068516,
# Validation Precision: 0.735251097025841,
# Validation F1: 0.6697757050854986
#
# Epoch 121,
# Loss: 0.3115067369871885,
# Validation Accuracy: 0.6871941272430668,
# Validation ROC: 0.7579657482389448,
# Validation Recall: 0.5758564437194127,
# Validation Precision: 0.7408184679958028,
# Validation F1: 0.6480036714089031
#
# Epoch 122,
# Loss: 0.3047581970788757,
# Validation Accuracy: 0.6829119086460033,
# Validation ROC: 0.7567820921896165,
# Validation Recall: 0.5693311582381729,
# Validation Precision: 0.7366754617414248,
# Validation F1: 0.6422820335863814
#
# Epoch 123,
# Loss: 0.298782492790626,
# Validation Accuracy: 0.6912724306688418,
# Validation ROC: 0.7544125346955177,
# Validation Recall: 0.6806688417618271,
# Validation Precision: 0.6954166666666667,
# Validation F1: 0.6879637262984336
#
# Epoch 124,
# Loss: 0.3197899701540944,
# Validation Accuracy: 0.6741435562805873,
# Validation ROC: 0.7421644015339212,
# Validation Recall: 0.601957585644372,
# Validation Precision: 0.7035271687321258,
# Validation F1: 0.6487912087912088
#
# Epoch 125,
# Loss: 0.48227491212784274,
# Validation Accuracy: 0.6682300163132137,
# Validation ROC: 0.7251550320808795,
# Validation Recall: 0.6268352365415987,
# Validation Precision: 0.6834148510449088,
# Validation F1: 0.6539034248032334
#
# Epoch 126,
# Loss: 0.3679376213966053,
# Validation Accuracy: 0.6798531810766721,
# Validation ROC: 0.7335759302922806,
# Validation Recall: 0.6619086460032626,
# Validation Precision: 0.6865482233502538,
# Validation F1: 0.6740033222591362
#
# Epoch 127,
# Loss: 0.3539893307786811,
# Validation Accuracy: 0.6890293637846656,
# Validation ROC: 0.738547485290165,
# Validation Recall: 0.7222675367047309,
# Validation Precision: 0.6772466539196941,
# Validation F1: 0.6990329583580027
#
# Epoch 128,
# Loss: 0.34061240994580794,
# Validation Accuracy: 0.6686378466557912,
# Validation ROC: 0.7493886703001047,
# Validation Recall: 0.5061174551386624,
# Validation Precision: 0.7498489425981874,
# Validation F1: 0.6043340637935233
#
# Epoch 129,
# Loss: 0.30916246072865466,
# Validation Accuracy: 0.6878058727569332,
# Validation ROC: 0.7585503826819137,
# Validation Recall: 0.6056280587275693,
# Validation Precision: 0.7247437774524158,
# Validation F1: 0.6598533659186847
#
# Epoch 130,
# Loss: 0.31379024577645603,
# Validation Accuracy: 0.6688417618270799,
# Validation ROC: 0.722603930207122,
# Validation Recall: 0.6146003262642741,
# Validation Precision: 0.6893870082342177,
# Validation F1: 0.6498490728762397
#
# Epoch 131,
# Loss: 0.3564906675574834,
# Validation Accuracy: 0.6816884176182708,
# Validation ROC: 0.7386107721765234,
# Validation Recall: 0.6300978792822186,
# Validation Precision: 0.7025920873124147,
# Validation F1: 0.6643732530638572
#
# Epoch 132,
# Loss: 0.34227932703223213,
# Validation Accuracy: 0.6617047308319739,
# Validation ROC: 0.7421066865547716,
# Validation Recall: 0.4902120717781403,
# Validation Precision: 0.7461204220980757,
# Validation F1: 0.5916810238739847
#
# Epoch 133,
# Loss: 0.33405479075271843,
# Validation Accuracy: 0.6939233278955954,
# Validation ROC: 0.7492477093639975,
# Validation Recall: 0.683115823817292,
# Validation Precision: 0.6982075864943726,
# Validation F1: 0.6905792620078335
#
# Epoch 134,
# Loss: 0.33067117966347487,
# Validation Accuracy: 0.6786296900489397,
# Validation ROC: 0.7489775966085548,
# Validation Recall: 0.5770799347471451,
# Validation Precision: 0.7241555783009211,
# Validation F1: 0.6423059464366773
#
# Epoch 135,
# Loss: 0.34421500968913693,
# Validation Accuracy: 0.668026101141925,
# Validation ROC: 0.7345522614957594,
# Validation Recall: 0.5244698205546493,
# Validation Precision: 0.7356979405034325,
# Validation F1: 0.6123809523809524
#
# Epoch 136,
# Loss: 0.34411246050452565,
# Validation Accuracy: 0.6765905383360522,
# Validation ROC: 0.7357235262887571,
# Validation Recall: 0.5783034257748777,
# Validation Precision: 0.7197969543147208,
# Validation F1: 0.6413387607417458
#
# Epoch 137,
# Loss: 0.3329005092867811,
# Validation Accuracy: 0.6751631321370309,
# Validation ROC: 0.7448133028536148,
# Validation Recall: 0.5220228384991843,
# Validation Precision: 0.7524985302763081,
# Validation F1: 0.6164218637129786
#
# Epoch 138,
# Loss: 0.32167772143011375,
# Validation Accuracy: 0.6792414355628059,
# Validation ROC: 0.749107995869803,
# Validation Recall: 0.5884991843393148,
# Validation Precision: 0.71898355754858,
# Validation F1: 0.6472303206997084
#
# Epoch 139,
# Loss: 0.31660676026771434,
# Validation Accuracy: 0.666394779771615,
# Validation ROC: 0.7464124402225836,
# Validation Recall: 0.5040783034257749,
# Validation Precision: 0.7463768115942029,
# Validation F1: 0.6017526777020448
#
# Epoch 140,
# Loss: 0.335418509058533,
# Validation Accuracy: 0.6849510603588908,
# Validation ROC: 0.7482267197400532,
# Validation Recall: 0.6427406199021207,
# Validation Precision: 0.7020044543429844,
# Validation F1: 0.671066638279753
#
# Epoch 141,
# Loss: 0.3077663700869883,
# Validation Accuracy: 0.6914763458401305,
# Validation ROC: 0.74989213785597,
# Validation Recall: 0.7120717781402937,
# Validation Precision: 0.6839012925969448,
# Validation F1: 0.6977022977022977
#
# Epoch 142,
# Loss: 0.31377247432155797,
# Validation Accuracy: 0.6692495921696574,
# Validation ROC: 0.7501889458683392,
# Validation Recall: 0.5265089722675367,
# Validation Precision: 0.7368721461187214,
# Validation F1: 0.6141769743101808
#
# Epoch 143,
# Loss: 0.3038191445632944,
# Validation Accuracy: 0.6863784665579119,
# Validation ROC: 0.7544051332068372,
# Validation Recall: 0.6353996737357259,
# Validation Precision: 0.7075386012715713,
# Validation F1: 0.6695315857327031
#
# Epoch 144,
# Loss: 0.30086143882732824,
# Validation Accuracy: 0.6810766721044046,
# Validation ROC: 0.751185152979623,
# Validation Recall: 0.5844208809135399,
# Validation Precision: 0.724469160768453,
# Validation F1: 0.6469525959367946
#
# Epoch 145,
# Loss: 0.2922484065597143,
# Validation Accuracy: 0.6994290375203915,
# Validation ROC: 0.7516487855570843,
# Validation Recall: 0.6810766721044046,
# Validation Precision: 0.7070279424216765,
# Validation F1: 0.6938097216452015
#
# Epoch 146,
# Loss: 0.2864608648642655,
# Validation Accuracy: 0.6721044045676998,
# Validation ROC: 0.7538069432284196,
# Validation Recall: 0.515905383360522,
# Validation Precision: 0.7502965599051008,
# Validation F1: 0.611406476558724
#
# Epoch 147,
# Loss: 0.29439897500342577,
# Validation Accuracy: 0.6827079934747146,
# Validation ROC: 0.7503121931292895,
# Validation Recall: 0.6300978792822186,
# Validation Precision: 0.7041932543299909,
# Validation F1: 0.6650882479552304
#
# Epoch 148,
# Loss: 0.2865981267164507,
# Validation Accuracy: 0.6865823817292006,
# Validation ROC: 0.7533280918596266,
# Validation Recall: 0.6231647634584013,
# Validation Precision: 0.7136851938346567,
# Validation F1: 0.6653603309383845
#
# Epoch 149,
# Loss: 0.3031963307519689,
# Validation Accuracy: 0.7000407830342578,
# Validation ROC: 0.7569128241020414,
# Validation Recall: 0.6998368678629691,
# Validation Precision: 0.7001223990208079,
# Validation F1: 0.6999796043238833
#
# Epoch 150,
# Loss: 0.2997804852960941,
# Validation Accuracy: 0.6814845024469821,
# Validation ROC: 0.7560269740186125,
# Validation Recall: 0.5893148450244698,
# Validation Precision: 0.7225,
# Validation F1: 0.6491464510332435
#
# Epoch 151,
# Loss: 0.29578289496393856,
# Validation Accuracy: 0.6920880913539967,
# Validation ROC: 0.756223155050044,
# Validation Recall: 0.6765905383360522,
# Validation Precision: 0.6982323232323232,
# Validation F1: 0.6872410936205469
#
# Epoch 152,
# Loss: 0.28254162537158506,
# Validation Accuracy: 0.6814845024469821,
# Validation ROC: 0.7561032343008603,
# Validation Recall: 0.5681076672104405,
# Validation Precision: 0.734704641350211,
# Validation F1: 0.640754369825207
#
# Epoch 153,
# Loss: 0.2792168328544604,
# Validation Accuracy: 0.6871941272430668,
# Validation ROC: 0.7535143765185526,
# Validation Recall: 0.617047308319739,
# Validation Precision: 0.717741935483871,
# Validation F1: 0.6635964912280702
#
# Epoch 154,
# Loss: 0.27821430042143364,
# Validation Accuracy: 0.6847471451876019,
# Validation ROC: 0.7521509225082431,
# Validation Recall: 0.6688417618270799,
# Validation Precision: 0.6908171861836563,
# Validation F1: 0.6796518856195607
#
# Epoch 155,
# Loss: 0.28589068671099915,
# Validation Accuracy: 0.6892332789559543,
# Validation ROC: 0.7559562856435736,
# Validation Recall: 0.6398858075040783,
# Validation Precision: 0.7099547511312218,
# Validation F1: 0.6731016731016731
#
# Epoch 156,
# Loss: 0.2783927114176828,
# Validation Accuracy: 0.6861745513866232,
# Validation ROC: 0.7552713568708436,
# Validation Recall: 0.6109298531810766,
# Validation Precision: 0.7191550648103696,
# Validation F1: 0.6606394707828004
#
# Epoch 157,
# Loss: 0.2723180659430811,
# Validation Accuracy: 0.691884176182708,
# Validation ROC: 0.7579749793090967,
# Validation Recall: 0.6382544861337683,
# Validation Precision: 0.7149383280036546,
# Validation F1: 0.6744236156000862
#
# Epoch 158,
# Loss: 0.2853452999642307,
# Validation Accuracy: 0.6837275693311582,
# Validation ROC: 0.7558143267539366,
# Validation Recall: 0.5884991843393148,
# Validation Precision: 0.7269521410579345,
# Validation F1: 0.6504394861392833
#
# Epoch 159,
# Loss: 0.278153230050876,
# Validation Accuracy: 0.6873980424143556,
# Validation ROC: 0.7560629835084853,
# Validation Recall: 0.6174551386623165,
# Validation Precision: 0.7178757705073494,
# Validation F1: 0.6638894979171235
#
# Epoch 160,
# Loss: 0.2721113094435064,
# Validation Accuracy: 0.6749592169657422,
# Validation ROC: 0.7516481202547309,
# Validation Recall: 0.5432300163132137,
# Validation Precision: 0.7375415282392026,
# Validation F1: 0.6256458431188351
#
# Epoch 161,
# Loss: 0.2746304998277453,
# Validation Accuracy: 0.6790375203915171,
# Validation ROC: 0.7492753194116598,
# Validation Recall: 0.5831973898858075,
# Validation Precision: 0.7214934409687185,
# Validation F1: 0.6450157870996842
#
# Epoch 162,
# Loss: 0.27704162007434363,
# Validation Accuracy: 0.692699836867863,
# Validation ROC: 0.7488521039521621,
# Validation Recall: 0.6827079934747146,
# Validation Precision: 0.6966292134831461,
# Validation F1: 0.6895983522142122
#
# Epoch 163,
# Loss: 0.2722281698829188,
# Validation Accuracy: 0.6772022838499184,
# Validation ROC: 0.7507456376124694,
# Validation Recall: 0.5648450244698205,
# Validation Precision: 0.728563913729616,
# Validation F1: 0.6363427521249713
#
# Epoch 164,
# Loss: 0.266931163517194,
# Validation Accuracy: 0.6829119086460033,
# Validation ROC: 0.7510299712057141,
# Validation Recall: 0.5929853181076672,
# Validation Precision: 0.7230233714569866,
# Validation F1: 0.6515796549406229
#
# Epoch 165,
# Loss: 0.2700505008138352,
# Validation Accuracy: 0.6763866231647635,
# Validation ROC: 0.749733795895883,
# Validation Recall: 0.5517944535073409,
# Validation Precision: 0.734926670287887,
# Validation F1: 0.6303284416491963
#
# Epoch 166,
# Loss: 0.27457252877737104,
# Validation Accuracy: 0.685562805872757,
# Validation ROC: 0.7385692739422358,
# Validation Recall: 0.6651712887438825,
# Validation Precision: 0.6934523809523809,
# Validation F1: 0.6790174854288094
#
# Epoch 167,
# Loss: 0.27499513861993236,
# Validation Accuracy: 0.672716150081566,
# Validation ROC: 0.7527926066280081,
# Validation Recall: 0.5379282218597063,
# Validation Precision: 0.7364600781686209,
# Validation F1: 0.6217299080839029
#
# Epoch 168,
# Loss: 0.261466473874906,
# Validation Accuracy: 0.6876019575856444,
# Validation ROC: 0.7521185721813135,
# Validation Recall: 0.6276508972267537,
# Validation Precision: 0.7131603336422614,
# Validation F1: 0.6676789587852494
#
# Epoch 169,
# Loss: 0.26443539875338057,
# Validation Accuracy: 0.6853588907014682,
# Validation ROC: 0.7470233541085081,
# Validation Recall: 0.6313213703099511,
# Validation Precision: 0.7078189300411523,
# Validation F1: 0.6673852123302436
#
# Epoch 170,
# Loss: 0.2735781967639923,
# Validation Accuracy: 0.6814845024469821,
# Validation ROC: 0.7490557696350684,
# Validation Recall: 0.6264274061990212,
# Validation Precision: 0.7039413382218148,
# Validation F1: 0.6629261976694001
#
# Epoch 171,
# Loss: 0.2705408157083033,
# Validation Accuracy: 0.6810766721044046,
# Validation ROC: 0.7520400665036233,
# Validation Recall: 0.5664763458401305,
# Validation Precision: 0.734920634920635,
# Validation F1: 0.6397973284200829
#
# Epoch 172,
# Loss: 0.26977208793066226,
# Validation Accuracy: 0.6945350734094616,
# Validation ROC: 0.7537024075961561,
# Validation Recall: 0.6606851549755302,
# Validation Precision: 0.7086614173228346,
# Validation F1: 0.6838328408611228
#
# Epoch 173,
# Loss: 0.2639084944944428,
# Validation Accuracy: 0.6825040783034257,
# Validation ROC: 0.7554000928762086,
# Validation Recall: 0.6133768352365416,
# Validation Precision: 0.7117841930903928,
# Validation F1: 0.6589266155531216
#
# Epoch 174,
# Loss: 0.2701160714321494,
# Validation Accuracy: 0.6873980424143556,
# Validation ROC: 0.7463459099872527,
# Validation Recall: 0.6859706362153344,
# Validation Precision: 0.6879345603271984,
# Validation F1: 0.6869511946089443
#
# Epoch 175,
# Loss: 0.2660466464606481,
# Validation Accuracy: 0.6859706362153344,
# Validation ROC: 0.7512586688896636,
# Validation Recall: 0.601957585644372,
# Validation Precision: 0.7235294117647059,
# Validation F1: 0.6571682991985752
#
# Epoch 176,
# Loss: 0.25434883865937347,
# Validation Accuracy: 0.6800570962479608,
# Validation ROC: 0.7505547789998642,
# Validation Recall: 0.5815660685154975,
# Validation Precision: 0.7242254951752158,
# Validation F1: 0.6451029178918797
#
# Epoch 177,
# Loss: 0.25385937718401513,
# Validation Accuracy: 0.683115823817292,
# Validation ROC: 0.7517577288174384,
# Validation Recall: 0.6349918433931484,
# Validation Precision: 0.7026173285198556,
# Validation F1: 0.6670951156812339
#
# Epoch 178,
# Loss: 0.25602276278629366,
# Validation Accuracy: 0.6847471451876019,
# Validation ROC: 0.7491642970814517,
# Validation Recall: 0.6447797716150081,
# Validation Precision: 0.7007978723404256,
# Validation F1: 0.6716227697536109
#
# Epoch 179,
# Loss: 0.2536286547634423,
# Validation Accuracy: 0.6892332789559543,
# Validation ROC: 0.7500281090244272,
# Validation Recall: 0.6957585644371941,
# Validation Precision: 0.6867954911433173,
# Validation F1: 0.6912479740680713
#
# Epoch 180,
# Loss: 0.25854202905967105,
# Validation Accuracy: 0.6916802610114192,
# Validation ROC: 0.753792888716206,
# Validation Recall: 0.6305057096247961,
# Validation Precision: 0.7184014869888475,
# Validation F1: 0.6715899218071243
#
# Epoch 181,
# Loss: 0.25470012516171614,
# Validation Accuracy: 0.6888254486133768,
# Validation ROC: 0.7514011267560655,
# Validation Recall: 0.6933115823817292,
# Validation Precision: 0.6871463217461601,
# Validation F1: 0.6902151847340642
#
# Epoch 182,
# Loss: 0.2592690285865569,
# Validation Accuracy: 0.6733278955954323,
# Validation ROC: 0.7466340690690291,
# Validation Recall: 0.58278955954323,
# Validation Precision: 0.7116533864541833,
# Validation F1: 0.6408071748878924
#
# Epoch 183,
# Loss: 0.27092344855058464,
# Validation Accuracy: 0.6792414355628059,
# Validation ROC: 0.7441410979883918,
# Validation Recall: 0.6048123980424144,
# Validation Precision: 0.71058936272161,
# Validation F1: 0.6534478960123375
#
# Epoch 184,
# Loss: 0.25376710919390283,
# Validation Accuracy: 0.6884176182707994,
# Validation ROC: 0.7497835272467925,
# Validation Recall: 0.6366231647634584,
# Validation Precision: 0.7101910828025477,
# Validation F1: 0.6713978494623656
#
# Epoch 185,
# Loss: 0.28903734045715984,
# Validation Accuracy: 0.6865823817292006,
# Validation ROC: 0.7518463803560167,
# Validation Recall: 0.6068515497553018,
# Validation Precision: 0.7219796215429404,
# Validation F1: 0.6594283181918901
#
# Epoch 186,
# Loss: 0.25635822862386703,
# Validation Accuracy: 0.6898450244698205,
# Validation ROC: 0.7519185656613504,
# Validation Recall: 0.6464110929853181,
# Validation Precision: 0.707905314872711,
# Validation F1: 0.6757620976337668
#
# Epoch 187,
# Loss: 0.2500599925603463,
# Validation Accuracy: 0.6829119086460033,
# Validation ROC: 0.7489107337220473,
# Validation Recall: 0.6080750407830342,
# Validation Precision: 0.7151079136690648,
# Validation F1: 0.6572625082653736
#
# Epoch 188,
# Loss: 0.24880901750796006,
# Validation Accuracy: 0.6755709624796085,
# Validation ROC: 0.74749139431406,
# Validation Recall: 0.5632137030995106,
# Validation Precision: 0.7264597580220936,
# Validation F1: 0.6345049391224443
#
# Epoch 189,
# Loss: 0.25861667598982974,
# Validation Accuracy: 0.6731239804241436,
# Validation ROC: 0.7457756627076741,
# Validation Recall: 0.5350734094616639,
# Validation Precision: 0.7391549295774648,
# Validation F1: 0.6207712325526378
#
# Epoch 190,
# Loss: 0.2658308507322488,
# Validation Accuracy: 0.6635399673735726,
# Validation ROC: 0.7455718306991794,
# Validation Recall: 0.5048939641109299,
# Validation Precision: 0.7395459976105138,
# Validation F1: 0.6000969461948619
#
# Epoch 191,
# Loss: 0.2545889452439566,
# Validation Accuracy: 0.6639477977161501,
# Validation ROC: 0.7399256591150414,
# Validation Recall: 0.5236541598694943,
# Validation Precision: 0.7278911564625851,
# Validation F1: 0.6091081593927894
#
# Epoch 192,
# Loss: 0.2552372068652113,
# Validation Accuracy: 0.6731239804241436,
# Validation ROC: 0.7437121442960968,
# Validation Recall: 0.5448613376835236,
# Validation Precision: 0.7328579264947888,
# Validation F1: 0.6250292397660818
#
# Epoch 193,
# Loss: 0.2604406558778076,
# Validation Accuracy: 0.6873980424143556,
# Validation ROC: 0.7481863857848837,
# Validation Recall: 0.6460032626427407,
# Validation Precision: 0.70431302801245,
# Validation F1: 0.6738991703892788
#
# Epoch 194,
# Loss: 0.2530858149503264,
# Validation Accuracy: 0.6849510603588908,
# Validation ROC: 0.7489872434926776,
# Validation Recall: 0.6284665579119086,
# Validation Precision: 0.7085057471264368,
# Validation F1: 0.6660903393127297
#
# Epoch 195,
# Loss: 0.25185516685344495,
# Validation Accuracy: 0.6880097879282219,
# Validation ROC: 0.7486199134308578,
# Validation Recall: 0.6721044045676998,
# Validation Precision: 0.6941870261162595,
# Validation F1: 0.6829672606713635
#
# Epoch 196,
# Loss: 0.2669334004144715,
# Validation Accuracy: 0.6798531810766721,
# Validation ROC: 0.7428570644465085,
# Validation Recall: 0.6064437194127243,
# Validation Precision: 0.7108030592734226,
# Validation F1: 0.6544894366197183
#
# Epoch 197,
# Loss: 0.2536681983680601,
# Validation Accuracy: 0.689437194127243,
# Validation ROC: 0.7502222109860046,
# Validation Recall: 0.6235725938009788,
# Validation Precision: 0.7181775481446688,
# Validation F1: 0.6675398384632176
#
# Epoch 198,
# Loss: 0.24632955490572056,
# Validation Accuracy: 0.6800570962479608,
# Validation ROC: 0.7457429797295678,
# Validation Recall: 0.6011419249592169,
# Validation Precision: 0.7138014527845037,
# Validation F1: 0.6526455612131946
#
# Epoch 199,
# Loss: 0.24411084333052466,
# Validation Accuracy: 0.6820962479608483,
# Validation ROC: 0.745650918516429,
# Validation Recall: 0.6386623164763459,
# Validation Precision: 0.6994193836534167,
# Validation F1: 0.6676614794286932
#
# Epoch 200,
# Loss: 0.3091887691898532,
# Validation Accuracy: 0.6847471451876019,
# Validation ROC: 0.7485480607767006,
# Validation Recall: 0.6574225122349103,
# Validation Precision: 0.6954270923209663,
# Validation F1: 0.6758909853249476
#
#
#
# Test Accuracy: 0.6729200652528549,
# Test ROC: 0.7340283358925297,
# Test Recall: 0.6313213703099511,
# Test Precision: 0.6886120996441281,
# Test F1: 0.6587234042553192

# %%
df = pd.DataFrame(history)
df.to_csv(f"results/results_without_GNN_epoch_{200}")

df = pd.DataFrame(final_results)
df.to_csv(f"results/final_result_without_GNN_epoch_{200}")
